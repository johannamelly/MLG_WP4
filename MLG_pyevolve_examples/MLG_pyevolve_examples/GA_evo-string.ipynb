# %%
from pyevolve import G1DList
from pyevolve import GSimpleGA
from pyevolve import Selectors
from pyevolve import Statistics

# %%
def fitness(chromosome):
    score = 0.0
    target = 'METHINKS_IT_IS_LIKE_A_WEASEL'
    # iterate over the chromosome
    for i in range(0,len(chromosome)):
        if chr(chromosome[i]) == target[i]:
            score += 1
    return score

# %%
def current_best(ga_engine):
    # Here you have access to the GA Engine
    best = ga.bestIndividual()
    for i in range(0,len(best)):
        print(chr(best[i]))
    return False

# %%
# Chromosome representation

# genome = List of elements
genome = G1DList.G1DList(28)

# elements = values in the range rangemin and rangemax
# ASCII(65) = 'A' .... ASCII(95) = '_'
genome.setParams(rangemin=65, rangemax=95)

# how to compute the fitness
genome.evaluator.set(fitness)

# GA initialisation
ga = GSimpleGA.GSimpleGA(genome)
ga.setPopulationSize(200)
ga.setMutationRate(0.05)
ga.setCrossoverRate(0.9)
ga.selector.set(Selectors.GTournamentSelector)
ga.setElitism(True)

# Number of generations
ga.setGenerations(500)

# In case we want to monitor the evolution process
# execute the function current_best every generation
#ga.stepCallback.set(current_best)

ga.evolve(freq_stats=10)

# Final best solution
best = ga.bestIndividual()

for i in range(0,len(best)):
    print(chr(best[i]))
# Out:
# Gen. 0 (0.00%): Max/Min/Avg Fitness(Raw) [1.03(4.00)/0.81(0.00)/0.86(0.86)]
# Gen. 10 (2.00%): Max/Min/Avg Fitness(Raw) [7.23(10.00)/4.80(2.00)/6.02(6.03)]
# Gen. 20 (4.00%): Max/Min/Avg Fitness(Raw) [13.82(18.00)/10.27(8.00)/11.52(11.52)]
# Gen. 30 (6.00%): Max/Min/Avg Fitness(Raw) [18.00(20.00)/12.60(11.00)/15.00(15.00)]
# Gen. 40 (8.00%): Max/Min/Avg Fitness(Raw) [20.60(23.00)/13.54(11.00)/17.17(17.17)]
# Gen. 50 (10.00%): Max/Min/Avg Fitness(Raw) [20.92(24.00)/15.08(13.00)/17.44(17.43)]
# Gen. 60 (12.00%): Max/Min/Avg Fitness(Raw) [21.88(24.00)/15.56(14.00)/18.23(18.23)]
# Gen. 70 (14.00%): Max/Min/Avg Fitness(Raw) [21.98(24.00)/15.53(14.00)/18.32(18.32)]
# Gen. 80 (16.00%): Max/Min/Avg Fitness(Raw) [21.86(24.00)/14.30(12.00)/18.22(18.22)]
# Gen. 90 (18.00%): Max/Min/Avg Fitness(Raw) [22.22(25.00)/15.36(13.00)/18.52(18.52)]
# Gen. 100 (20.00%): Max/Min/Avg Fitness(Raw) [22.37(26.00)/16.29(14.00)/18.64(18.64)]
# Gen. 110 (22.00%): Max/Min/Avg Fitness(Raw) [22.87(26.00)/16.83(15.00)/19.05(19.05)]
# Gen. 120 (24.00%): Max/Min/Avg Fitness(Raw) [23.14(26.00)/16.82(15.00)/19.28(19.28)]
# Gen. 130 (26.00%): Max/Min/Avg Fitness(Raw) [22.78(26.00)/15.75(13.00)/18.99(18.98)]
# Gen. 140 (28.00%): Max/Min/Avg Fitness(Raw) [23.27(26.00)/16.81(15.00)/19.39(19.39)]
# Gen. 150 (30.00%): Max/Min/Avg Fitness(Raw) [22.49(26.00)/16.29(14.00)/18.74(18.74)]
# Gen. 160 (32.00%): Max/Min/Avg Fitness(Raw) [22.63(26.00)/16.29(14.00)/18.86(18.86)]
# Gen. 170 (34.00%): Max/Min/Avg Fitness(Raw) [22.03(26.00)/16.26(14.00)/18.36(18.36)]
# Gen. 180 (36.00%): Max/Min/Avg Fitness(Raw) [22.37(26.00)/16.29(14.00)/18.64(18.64)]
# Gen. 190 (38.00%): Max/Min/Avg Fitness(Raw) [23.22(26.00)/16.24(14.00)/19.35(19.35)]
# Gen. 200 (40.00%): Max/Min/Avg Fitness(Raw) [23.26(26.00)/16.23(14.00)/19.38(19.39)]
# Gen. 210 (42.00%): Max/Min/Avg Fitness(Raw) [22.90(26.00)/16.83(15.00)/19.09(19.09)]
# Gen. 220 (44.00%): Max/Min/Avg Fitness(Raw) [23.63(26.00)/17.39(16.00)/19.69(19.69)]
# Gen. 230 (46.00%): Max/Min/Avg Fitness(Raw) [22.69(26.00)/16.29(14.00)/18.91(18.91)]
# Gen. 240 (48.00%): Max/Min/Avg Fitness(Raw) [22.74(27.00)/17.09(15.00)/18.95(18.95)]
# Gen. 250 (50.00%): Max/Min/Avg Fitness(Raw) [23.04(27.00)/17.13(15.00)/19.20(19.20)]
# Gen. 260 (52.00%): Max/Min/Avg Fitness(Raw) [23.06(27.00)/17.13(15.00)/19.22(19.22)]
# Gen. 270 (54.00%): Max/Min/Avg Fitness(Raw) [22.29(27.00)/16.12(13.00)/18.57(18.57)]
# Gen. 280 (56.00%): Max/Min/Avg Fitness(Raw) [23.95(27.00)/17.71(16.00)/19.95(19.95)]
# Gen. 290 (58.00%): Max/Min/Avg Fitness(Raw) [23.32(27.00)/16.64(14.00)/19.43(19.43)]
# Gen. 300 (60.00%): Max/Min/Avg Fitness(Raw) [23.49(27.00)/17.16(15.00)/19.57(19.57)]
# Gen. 310 (62.00%): Max/Min/Avg Fitness(Raw) [23.86(27.00)/17.71(16.00)/19.89(19.89)]
# Gen. 320 (64.00%): Max/Min/Avg Fitness(Raw) [23.91(27.00)/17.71(16.00)/19.93(19.93)]
# Gen. 330 (66.00%): Max/Min/Avg Fitness(Raw) [23.18(27.00)/16.64(14.00)/19.32(19.32)]
# Gen. 340 (68.00%): Max/Min/Avg Fitness(Raw) [23.50(27.00)/16.63(14.00)/19.58(19.59)]
# Gen. 350 (70.00%): Max/Min/Avg Fitness(Raw) [23.37(27.00)/17.68(16.00)/19.48(19.48)]
# Gen. 360 (72.00%): Max/Min/Avg Fitness(Raw) [24.31(27.00)/17.70(16.00)/20.26(20.26)]
# Gen. 370 (74.00%): Max/Min/Avg Fitness(Raw) [23.93(27.00)/17.15(15.00)/19.94(19.94)]
# Gen. 380 (76.00%): Max/Min/Avg Fitness(Raw) [23.18(27.00)/17.15(15.00)/19.32(19.32)]
# Gen. 390 (78.00%): Max/Min/Avg Fitness(Raw) [23.53(27.00)/17.69(16.00)/19.61(19.61)]
# Gen. 400 (80.00%): Max/Min/Avg Fitness(Raw) [23.74(27.00)/17.71(16.00)/19.79(19.79)]
# Gen. 410 (82.00%): Max/Min/Avg Fitness(Raw) [23.07(27.00)/17.14(15.00)/19.23(19.23)]
# Gen. 420 (84.00%): Max/Min/Avg Fitness(Raw) [23.75(27.00)/16.61(14.00)/19.79(19.79)]
# Gen. 430 (86.00%): Max/Min/Avg Fitness(Raw) [23.51(27.00)/17.16(15.00)/19.59(19.59)]
# Gen. 440 (88.00%): Max/Min/Avg Fitness(Raw) [23.60(27.00)/16.63(14.00)/19.67(19.67)]
# Gen. 450 (90.00%): Max/Min/Avg Fitness(Raw) [23.70(27.00)/17.16(15.00)/19.75(19.75)]
# Gen. 460 (92.00%): Max/Min/Avg Fitness(Raw) [23.39(27.00)/16.64(14.00)/19.49(19.49)]
# Gen. 470 (94.00%): Max/Min/Avg Fitness(Raw) [23.18(27.00)/17.15(15.00)/19.32(19.32)]
# Gen. 480 (96.00%): Max/Min/Avg Fitness(Raw) [22.97(27.00)/17.12(15.00)/19.14(19.14)]
# Gen. 490 (98.00%): Max/Min/Avg Fitness(Raw) [23.23(27.00)/17.66(16.00)/19.36(19.36)]
# Gen. 500 (100.00%): Max/Min/Avg Fitness(Raw) [22.53(27.00)/16.60(14.00)/18.77(18.77)]
# Total time elapsed: 9.897 seconds.
# I
# E
# T
# H
# I
# N
# K
# S
# _
# I
# T
# _
# I
# S
# _
# L
# I
# K
# E
# _
# A
# _
# W
# E
# A
# S
# E
# L
